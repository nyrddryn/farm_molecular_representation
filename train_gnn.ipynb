# %%
# !python src/gen_FG_vocab.py data/cleaned_smiles.csv data/fg_vocab.pkl

# %%
# !python src/gen_FG_KG.py --vocab_path data/fg_vocab.pkl --FGKG_path data/fgkg.pkl

# %%
# !python src/train_FG_KGE.py data/fgkg.pkl checkpoints data/feature_dict.pkl

# %%
# !python src/gen_FG_molecular_graph.py data/cleaned_smiles.csv data/feature_dict.pkl data/fg_molecular_graph.pkl

# %%
# !python src/train_GCN_link_prediction.py --data_path data/fg_molecular_graph.pkl --checkpoint_path gnn_checkpoint/
# Out:
# /home/hoangcm462/miniconda3/envs/farm/lib/python3.10/site-packages/torch_geometric/deprecation.py:12: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Epoch 1: 100%|███████████████████████████████| 770/770 [00:04<00:00, 172.23it/s]
# Training loss: nan
# Epoch 2: 100%|███████████████████████████████| 770/770 [00:04<00:00, 171.04it/s]
# Training loss: 0.006458494977338781
# Epoch 3: 100%|███████████████████████████████| 770/770 [00:04<00:00, 181.09it/s]
# Training loss: 0.0041688651330474245
# Epoch 4: 100%|███████████████████████████████| 770/770 [00:03<00:00, 193.43it/s]
# Training loss: 0.005838168730023627
# Epoch 5: 100%|███████████████████████████████| 770/770 [00:04<00:00, 154.38it/s]
# Training loss: 0.00023295458810828782
# Epoch 6: 100%|███████████████████████████████| 770/770 [00:04<00:00, 174.55it/s]
# Training loss: 8.778680642641923e-05
# ...

# %%
# !python src/gen_contrastive_learning_data.py --link_prediction_model gnn_checkpoint/link_prediction_model_epoch40.pth --fgkg_embedding_path data/feature_dict.pkl --corpus_path data/cleaned_smiles.csv --save_path data/contrastive_data.pkl
# Out:
#   0%|                                                  | 0/1540 [00:00<?, ?it/s]/home/hoangcm462/farm_molecular_representation/src/gen_contrastive_learning_data.py:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x).float()
#   2%|▋                                       | 28/1540 [00:00<00:05, 277.97it/s]Error processing SMILES CCCCCCCCCCCCCCCCCC(=O)O: cannot unpack non-iterable NoneType object
# Error processing SMILES CC(Cl)(Cl)Cl: cannot unpack non-iterable NoneType object
# Error processing SMILES *S: cannot unpack non-iterable NoneType object
# Error processing SMILES O=S(O)O: cannot unpack non-iterable NoneType object
#   5%|██▏                                     | 83/1540 [00:00<00:05, 260.36it/s]Error processing SMILES [Cl-]: cannot unpack non-iterable NoneType object
# ...

# %%
# !python src/train_contrastive_bert.py --train_corpus_path data/contrastive_train_corpus.pkl --val_corpus_path data/contrastive_val_corpus.pkl --tokenizer_path kegg_tokenizer/ --pretrained_model_path bert_model_output/checkpoint-10000-new --output_dir contrastive_bert/
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at bert_model_output/checkpoint-10000-new and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...
#   0%|                                         | 1/390 [00:21<2:17:00, 21.13s/it]^C
